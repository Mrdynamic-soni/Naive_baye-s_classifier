# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("IMDB_Dataset.csv")

# %%
df
# Out:
#                                                   review sentiment
# 0      One of the other reviewers has mentioned that ...  positive
# 1      A wonderful little production. <br /><br />The...  positive
# 2      I thought this was a wonderful way to spend ti...  positive
# 3      Basically there's a family where a little boy ...  negative
# 4      Petter Mattei's "Love in the Time of Money" is...  positive
# ...                                                  ...       ...
# 49995  I thought this movie did a down right good job...  positive
# 49996  Bad plot, bad dialogue, bad acting, idiotic di...  negative
# 49997  I am a Catholic taught in parochial elementary...  negative
# 49998  I'm going to have to disagree with the previou...  negative
# 49999  No one expects the Star Trek movies to be high...  negative
#
# [50000 rows x 2 columns]

# %%
df["review"][0]
# Out:
# "One of the other reviewers has mentioned that after watching just 1 Oz episode you'll be hooked. They are right, as this is exactly what happened with me.<br /><br />The first thing that struck me about Oz was its brutality and unflinching scenes of violence, which set in right from the word GO. Trust me, this is not a show for the faint hearted or timid. This show pulls no punches with regards to drugs, sex or violence. Its is hardcore, in the classic use of the word.<br /><br />It is called OZ as that is the nickname given to the Oswald Maximum Security State Penitentary. It focuses mainly on Emerald City, an experimental section of the prison where all the cells have glass fronts and face inwards, so privacy is not high on the agenda. Em City is home to many..Aryans, Muslims, gangstas, Latinos, Christians, Italians, Irish and more....so scuffles, death stares, dodgy dealings and shady agreements are never far away.<br /><br />I would say the main appeal of the show is due to the 
# ...

# %% [markdown]
# TEXT CLEANING STEPS
# 1. Sample 10000 rows
# 2. Removal of all htnl tags
# 3. Remove special charatcers
# 4. Converting everythong to lower case
# 5. Removing of stop words
# 6. Stemming

# %%
new_df= df.sample(10000)
#sample() function to take sample from data

# %%
new_df.shape
#to check the shape of our dataset
# Out:
# (10000, 2)

# %%
dir(new_df)
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
# ...

# %%
new_df.info()

# info() is use to check the for missing data points
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10000 entries, 12895 to 29487
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   review     10000 non-null  object
#  1   sentiment  10000 non-null  object
# dtypes: object(2)
# memory usage: 234.4+ KB

# %%
#label encoding without using label encoder library
new_df['sentiment'].replace({'positive':1,'negative':0},inplace = True)

# %%
new_df
# Out:
#                                                   review  sentiment
# 12895  A question immediately arises in this extremel...          1
# 813    This film is a lyrical and romantic memoir tol...          1
# 31929  This movie was awful and an insult to the view...          0
# 35260  I am proud to say I own an uncut copy of this ...          1
# 47820  As the faux-Russian scientist says two-thirds ...          0
# ...                                                  ...        ...
# 26741  They call this film "euro trash horror". <br /...          0
# 6991   I don't even know where to start. I did not li...          0
# 31463  I'm not usually a fan of strictly romantic mov...          1
# 10149  This is one heck of a sleazy film. Like so man...          0
# 29487  I actually liked this movie. Sure, the acting ...          0
#
# [10000 rows x 2 columns]

# %%
# just a check code 
import re 
clean = re.compile('<.*?>')  # to look for the pattern on the text
re.sub(clean,'',new_df.iloc[0].review)
# sun takes three arguements pattern that has to searched and with what should it be
# replaced and where to apply rest pf two
# Out:
# "A question immediately arises in this extremely idiosyncratic film: Who are the crazy people?The answer become less clear as the film goes on.Renee Zellweger loses the whiney note in her voice and, while her voice is still high, she is incredibly effective as the shell-shocked Betty. In fact, she is so effective I almost wanted her to be just a little more crazy because her created reality was so believable.This is the first time Ms Zellweger has been called upon to carry a film and she is more than equal to the task.Chris Rock \x96 though as foul-mouthed as usual \x96 is fairly subdued as Wesley. He is able to sublimate his manic energy and it only occasionally surfaces and always when it is needed most.There are some interesting allusions: the first time you see Betty she is dressed almost exactly like Dorothy Gale from the `Wizard of Oz' \x96 then later in the film she is compared to Dorothy when she says she has never been out of Kansas before. At one point the song that Doris D
# ...

# %%
# function to clean data of reveiews
def clean_reveiew(text):
    clean = re.compile('<.*?>')
    return re.sub(clean,'',text)

# %%
new_df['review']=new_df['review'].apply(clean_reveiew)
new_df
# Out:
#                                                   review  sentiment
# 12895  A question immediately arises in this extremel...          1
# 813    This film is a lyrical and romantic memoir tol...          1
# 31929  This movie was awful and an insult to the view...          0
# 35260  I am proud to say I own an uncut copy of this ...          1
# 47820  As the faux-Russian scientist says two-thirds ...          0
# ...                                                  ...        ...
# 26741  They call this film "euro trash horror". Well,...          0
# 6991   I don't even know where to start. I did not li...          0
# 31463  I'm not usually a fan of strictly romantic mov...          1
# 10149  This is one heck of a sleazy film. Like so man...          0
# 29487  I actually liked this movie. Sure, the acting ...          0
#
# [10000 rows x 2 columns]

# %%
def make_lower(text):
    return text.lower()

# %%
new_df['review']=new_df['review'].apply(make_lower)
new_df
# Out:
#                                                   review  sentiment
# 12895  a question immediately arises in this extremel...          1
# 813    this film is a lyrical and romantic memoir tol...          1
# 31929  this movie was awful and an insult to the view...          0
# 35260  i am proud to say i own an uncut copy of this ...          1
# 47820  as the faux-russian scientist says two-thirds ...          0
# ...                                                  ...        ...
# 26741  they call this film "euro trash horror". well,...          0
# 6991   i don't even know where to start. i did not li...          0
# 31463  i'm not usually a fan of strictly romantic mov...          1
# 10149  this is one heck of a sleazy film. like so man...          0
# 29487  i actually liked this movie. sure, the acting ...          0
#
# [10000 rows x 2 columns]

# %%
new_df
# Out:
#                                                   review  sentiment
# 12895  a question immediately arises in this extremel...          1
# 813    this film is a lyrical and romantic memoir tol...          1
# 31929  this movie was awful and an insult to the view...          0
# 35260  i am proud to say i own an uncut copy of this ...          1
# 47820  as the faux-russian scientist says two-thirds ...          0
# ...                                                  ...        ...
# 26741  they call this film "euro trash horror". well,...          0
# 6991   i don't even know where to start. i did not li...          0
# 31463  i'm not usually a fan of strictly romantic mov...          1
# 10149  this is one heck of a sleazy film. like so man...          0
# 29487  i actually liked this movie. sure, the acting ...          0
#
# [10000 rows x 2 columns]

# %%
new_df.shape
# Out:
# (10000, 2)

# %%
def remove_special_character(text):
    x=''
    for i in text:
        if i.isalnum():
            x=x+i
        else:
            x=x+' '
    return x

# %%
new_df['review']  = new_df['review'].apply(remove_special_character)

# %%
new_df
# Out:
#                                                   review  sentiment
# 12895  a question immediately arises in this extremel...          1
# 813    this film is a lyrical and romantic memoir tol...          1
# 31929  this movie was awful and an insult to the view...          0
# 35260  i am proud to say i own an uncut copy of this ...          1
# 47820  as the faux russian scientist says two thirds ...          0
# ...                                                  ...        ...
# 26741  they call this film  euro trash horror   well ...          0
# 6991   i don t even know where to start  i did not li...          0
# 31463  i m not usually a fan of strictly romantic mov...          1
# 10149  this is one heck of a sleazy film  like so man...          0
# 29487  i actually liked this movie  sure  the acting ...          0
#
# [10000 rows x 2 columns]

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Acer\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords

# %%
stop = stopwords.words('english')

# %%
def remove_stopwords(text):
    temp = []
    for word in text.split():
        if word not in stop:
            temp.append(word)
    return temp

# %%
new_df["review"]=new_df["review"].apply(remove_stopwords)
new_df
# Out:
#                                                   review  sentiment
# 12895  [question, immediately, arises, extremely, idi...          1
# 813    [film, lyrical, romantic, memoir, told, eyes, ...          1
# 31929  [movie, awful, insult, viewer, stupid, script,...          0
# 35260  [proud, say, uncut, copy, choice, chunk, 70, c...          1
# 47820  [faux, russian, scientist, says, two, thirds, ...          0
# ...                                                  ...        ...
# 26741  [call, film, euro, trash, horror, well, horror...          0
# 6991   [even, know, start, like, behave, like, story,...          0
# 31463  [usually, fan, strictly, romantic, movies, hea...          1
# 10149  [one, heck, sleazy, film, like, many, women, c...          0
# 29487  [actually, liked, movie, sure, acting, flat, p...          0
#
# [10000 rows x 2 columns]

# %%
# for stemming
from nltk.stem.porter import PorterStemmer
ps =PorterStemmer()

# %%
y=[]
def stem_word(text):
    for word in text:
        y.append(ps.stem(word))
    x=y[:]
    y.clear()
    return x

# %%
new_df["review"]=new_df["review"].apply(stem_word)

# %%
new_df
# Out:
#                                                   review  sentiment
# 12895  [question, immedi, aris, extrem, idiosyncrat, ...          1
# 813    [film, lyric, romant, memoir, told, eye, eleve...          1
# 31929  [movi, aw, insult, viewer, stupid, script, bad...          0
# 35260  [proud, say, uncut, copi, choic, chunk, 70, cr...          1
# 47820  [faux, russian, scientist, say, two, third, wa...          0
# ...                                                  ...        ...
# 26741  [call, film, euro, trash, horror, well, horror...          0
# 6991   [even, know, start, like, behav, like, stori, ...          0
# 31463  [usual, fan, strictli, romant, movi, heard, go...          1
# 10149  [one, heck, sleazi, film, like, mani, women, c...          0
# 29487  [actual, like, movi, sure, act, flat, plot, vi...          0
#
# [10000 rows x 2 columns]

# %%
def join_back(text):
    return " ".join(text)

# %%
new_df["review"]=new_df["review"].apply(join_back)
new_df
# Out:
#                                                   review  sentiment
# 12895  question immedi aris extrem idiosyncrat film c...          1
# 813    film lyric romant memoir told eye eleven year ...          1
# 31929  movi aw insult viewer stupid script bad cast e...          0
# 35260  proud say uncut copi choic chunk 70 crown inte...          1
# 47820  faux russian scientist say two third way movi ...          0
# ...                                                  ...        ...
# 26741  call film euro trash horror well horror film t...          0
# 6991   even know start like behav like stori much inj...          0
# 31463  usual fan strictli romant movi heard good stun...          1
# 10149  one heck sleazi film like mani women chain fil...          0
# 29487  actual like movi sure act flat plot villain la...          0
#
# [10000 rows x 2 columns]

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv =  CountVectorizer(max_features=1000)

# %%
temp = cv.fit_transform(new_df['review']).toarray()

# %%
temp.shape
# Out:
# (10000, 1000)

# %%
out = new_df.iloc[:,-1].values
out
# Out:
# array([1, 1, 0, ..., 1, 0, 0], dtype=int64)

# %%
out.shape
# Out:
# (10000,)

# %%
# split data in training set and testing set
from sklearn.model_selection import train_test_split

# %%
xtrain, xtest, ytrain,ytest = train_test_split(temp,out, test_size=0.2)

# %%
from sklearn.naive_bayes import GaussianNB,MultinomialNB,BernoulliNB

# %%
clf1 = GaussianNB()
clf2 = MultinomialNB()
clf3 = BernoulliNB()

# %%
clf1.fit(xtrain,ytrain)
clf2.fit(xtrain,ytrain)
clf3.fit(xtrain,ytrain)
# Out:
# BernoulliNB()

# %%
y_pred1 = clf1.predict(xtest)
y_pred2 = clf2.predict(xtest)
y_pred3 = clf3.predict(xtest)

# %%
from sklearn.metrics import accuracy_score

# %%
print("Gaussian",accuracy_score(ytest,y_pred1))
print("Multinomial",accuracy_score(ytest,y_pred2))
print("Bernauli",accuracy_score(ytest,y_pred3))
# Out:
# Gaussian 0.7775
# Multinomial 0.827
# Bernauli 0.84
